# %% [markdown]
# # Import libraries

# %% [markdown]
# !pip install pandas

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
from fastai.vision.all import *

import cv2
import pytesseract
from matplotlib import pyplot as plt
import os
from pathlib import Path
import requests
pytesseract.pytesseract.tesseract_cmd = r'C:\\Users\\dkmjja\\AppData\\Local\\Programs\\Tesseract-OCR\\tesseract.exe'

# %matplotlib inline

# %% [markdown]
# # Import dataset

# %%
os.getcwd()
# Out:
# 'c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\src'

# %%
path = Path('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers')

# %%
fns = get_image_files(path,'/images')

# %%
print(fns)
# Out:
# [Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/0-7513-00772-6.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/3-528-24010-5.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/953-6166-40-2.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-0-06-240995-9.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-0-140-44766-8.jpg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-118-13271-5.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-491-92757-1.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-58234-180-4.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-62315-916-0.jpeg'), Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/G
# ...

# %%
labels = [x.name.split('.')[0] for x in fns]

# %%
labels
# Out:
# ['0-7513-00772-6',
#  '3-528-24010-5',
#  '953-6166-40-2',
#  '978-0-06-240995-9',
#  '978-0-140-44766-8',
#  '978-1-118-13271-5',
#  '978-1-491-92757-1',
#  '978-1-58234-180-4',
#  '978-1-62315-916-0',
#  '978-1-78439-390-8-55499',
#  '978-3-86848-981-1',
#  '978-953-13-1832-7']

# %%
dls = ImageDataLoaders.from_lists(path, fns, labels = labels, bs=5)

# %%
os.path.join(path, 'images')
# Out:
# 'c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images'

# %%
os.listdir(os.path.join(path,'images'))
# Out:
# ['0-7513-00772-6.jpeg',
#  '3-528-24010-5.jpeg',
#  '953-6166-40-2.jpeg',
#  '978-0-06-240995-9.jpeg',
#  '978-0-140-44766-8.jpg',
#  '978-1-118-13271-5.jpeg',
#  '978-1-491-92757-1.jpeg',
#  '978-1-58234-180-4.jpeg',
#  '978-1-62315-916-0.jpeg',
#  '978-1-78439-390-8-55499.jpeg',
#  '978-3-86848-981-1.jpeg',
#  '978-953-13-1832-7.jpeg']

# %% [markdown]
# ## Setup tesseract and test with cv2

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\0-7513-00772-6.jpeg', cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)

# %%
text
# Out:
# 'me “i\nSel Se\na ea\n\nPi DORLING KINDERSLEY ~\n— HANDBOOKS —:\n\nINSECTS\n\nSPIDERS AND OTHER TERRESTRIAL ARTHROPODS\nGeorge C. McGavin\n\n{|\n\nDigger wasp\n\nEresid spider\n\nFrog-hopper Cicada Velvet ant\n\nThe clearest recognition guides available\n\n'

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\3-528-24010-5.jpeg', cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
fns[0]
# Out:
# Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/0-7513-00772-6.jpeg')

# %% [markdown]
# Apparently it doesn´t work that well with german!

# %% [markdown]
# Check more book titles

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\953-6166-40-2.jpeg', cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)

# %%
text
# Out:
# ''

# %% [markdown]
# Really bad, need to play with processing of images here!

# %%
fns
# Out:
# (#12) [Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/0-7513-00772-6.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/3-528-24010-5.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/953-6166-40-2.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-0-06-240995-9.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-0-140-44766-8.jpg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-118-13271-5.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-491-92757-1.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-58234-180-4.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitHub/book-covers/images/978-1-62315-916-0.jpeg'),Path('c:/Users/dkmjja/OneDrive - Chr Hansen/Documents/GitH
# ...

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\978-0-06-240995-9.jpeg', cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)

# %%
text
# Out:
# ''

# %% [markdown]
# So Bourdain also has creative covers that require more image preprocessing.
# Let´s check more images.

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\978-1-118-13271-5.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)

# %%
text
# Out:
# 'PAB ANGRY\n\nea\n\n’\n\nTECHNIQUES AND RECIPES\n\nLu\n©\ns<\n©\n©\nfae)\nw\noO\nLu\ns<\n<\nfaa\n<\n\n'

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\978-1-491-92757-1.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)

# %%
text
# Out:
# "O'REILLY’\n\nESSENTIAL\n\nSSIS SNC GSES\ntie.\n\nae\n\na\n\ni\nlA | ;\n\n{\n4\n\nWeis A\nZs, Ujp YY My,\n\ny 4 {\nVg MU\n\nA\n\nZ, Y/ Vi Wy\n\n"

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\978-1-62315-916-0.jpeg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)
text
# Out:
# 'x ,\n\nBRIAN MacDUCKSTON 205\n\nTe 7\n\nwere\nae\net\n\n%\nS\n%\n\n* +\n\nre eo\n\n'

# %% [markdown]
# And now some children´s books with colorful covers

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\978-3-86848-981-1.jpeg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)
text
# Out:
# ''

# %%
img = cv2.imread('c:\\Users\\dkmjja\\OneDrive - Chr Hansen\\Documents\\GitHub\\book-covers\\images\\978-953-13-1832-7.jpeg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img)

# %%
text = pytesseract.image_to_string(img)
text
# Out:
# '“... prakti¢an i zabavan pogled na prvu godinu i pol djetetova zivota,\nprepun zanimljivih opazanja i prakti¢nih savjeta.”\n\ndr. T. Berry Brazelton, professor emeritus\nMedicinski fakultet na Harvardu\n\nWwW\nUs! fg\ndr. sc. Hetty van de Rijt\n& : dr. sc. Frans Plooij\nXaviera Plas-Plooij\n\ntiedni\n\nKako potaknuti najvaznije razvojne tjedne u prvih\n\ndvadeset mjeseci djetetova zivota i kako deset\n\npredvidljivih, prekrasnih i nemirnih faza pretvoriti\n\nu Carobne skokove napretka\n\ns -PULS\n\ns\n@\n\n'

# %% [markdown]
# ## Check whether book title was correctly recognized

# %% [markdown]
# Well, that´s a bummer! In order to use the ISBNdb api, you need to pay a fee. So skipping this validation step, until a free api found.

# %%
os.path.join('https://api2.isbndb.com/book', '07513007726')
# Out:
# 'https://api2.isbndb.com/book\\07513007726'

# %%
h = {'Authorization': 'moj_kljuc_test'}
resp = requests.get("https://api2.isbndb.com/book/07513007726", headers=h)
print(resp.json())
# Out:
# {'message': 'User is not authorized to access this resource with an explicit deny'}
